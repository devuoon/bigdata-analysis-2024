# %% [markdown]
# ## 빅데이터 실습
#
# ### 스타벅스 입지 분석
#
# #### 데이터 수집
#
# ##### 웹사이트 제공 엑셀파일 수정

# %%
# 필수 라이브러리 사용 등록
import pandas as pd
import numpy as np

# %%
dfSeoulManicipality = pd.read_excel('./data/전국_시군구_위경도.xlsx', header=2)
dfSeoulManicipality.tail()
# Out:
#        강원고성군  강원    고성군  128.470164  38.377961
# 288    충청충주시  충청    충주시  127.928144  36.988181
# 289    충청태안군  충청    태안군  126.299975  36.742667
# 290  충청한누리대로  충청  한누리대로  127.289926  36.485450
# 291    충청홍성군  충청    홍성군  126.662908  36.598361
# 292    충청대전시  충청    대전시  127.384862  36.350630

# %%
# 서울 필터링
condition = dfSeoulManicipality['do'] == '서울'
dfSeoulGeo = dfSeoulManicipality[condition]

# %%
dfSeoulGeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 138 to 162
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     25 non-null     object
#  1   do         25 non-null     object
#  2   city       25 non-null     object
#  3   longitude  25 non-null     float64
#  4   latitude   25 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
# 필요로 만든 데이터는 항상 저장해둘 것
dfSeoulGeo.to_excel('./data/수정_서울_시군구_위경도.xlsx', index=False)

# %%
## 서울시 구별 인구데이터 로드
columns = ['구','세대소계','성별소계','남자','여자','한국인소계','남자','여자','등록외국인소계','남자','여자','세대당인구','65세이상']
dfSeoulPop = pd.read_excel('./data/서울시_구별_인구데이터.xlsx', header=2)
dfSeoulPop
# Out:
# c:\DEV\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    동별(1) 동별(2)       소계     소계.1       남자       여자     소계.2     남자.1     여자.1  \
# 0     합계    소계  4475726  9655918  4660459  4995459  9407540  4552501  4855039
# 1    NaN   종로구    72304   151127    72222    78905   139945    67625    72320
# 2    NaN    중구    64609   131825    63661    68164   121405    58788    62617
# 3    NaN   용산구   109360   230692   111646   119046   216152   103804   112348
# 4    NaN   성동구   133366   285543   138109   147434   278366   135143   143223
# 5    NaN   광진구   170388   351959   168059   183900   336604   161892   174712
# 6    NaN  동대문구   173091   359113   173936   185177   341238   167468   173770
# 7    NaN   중랑구   187900   387940   189874   198066   382797   187844   194953
# 8    NaN   성북구   197607   440089   209742   230347   427671   205245   222426
# 9    NaN   강북구   144269   294804   142202   152602   290155   140589   149566
# 10   NaN   도봉구   138210   310133   150104   160029   307740   149281   158459
# 11   NaN   노원구   218367   504423   241959   262464   499989   240084   259905
# 12   NaN   은평구   215776   471155   223585   247570   467098   221977   245121
# 13   NaN  서대문구   147333   321379   150451   170928   307441   146119   161322
# 14   NaN   마포구   181192   375639   174343   201296   364257   170296   193961
# 15   NaN   양천구   181072   440591   214964   225627   437401   213648   223753
# 16   NaN   강서구   274249   569978   272961   297017   564339   270491   293848
# 17   NaN   구로구   184467   416815   205465   211350   393929   193258   200671
# 18   NaN   금천구   120650   242076   122132   119944   228611   115038   113573
# 19   NaN  영등포구   190761   398290   195857   202433   375586   184175   191411
